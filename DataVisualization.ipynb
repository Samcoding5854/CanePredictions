# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data into a DataFrame
data = pd.read_csv('Lucknow_data.csv')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# One-hot encode the 'Season' column
data_encoded = pd.get_dummies(data, columns=['Season'])

# Reordering columns with 'Price' at the end
columns_ordered = [col for col in data_encoded.columns if col != 'Price'] + ['Price']
data_encoded = data_encoded[columns_ordered]

# Selecting columns for correlation matrix (excluding 'Year')
correlation_data = data_encoded.drop(['Year'], axis=1)

# Calculating correlation matrix
correlation_matrix = correlation_data.corr()

# Plotting correlation matrix as heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Parameters (Excluding Year)')
plt.show()

# %%
# Parameter Visualization
# Plotting minimum and maximum temperature over the years for each season
seasons = data['Season'].unique()
plt.figure(figsize=(12, 6))
for season in seasons:
    season_data = data[data['Season'] == season]
    plt.plot(season_data['Year'], season_data['Min_Rainfall'], label=f'{season} Min Rainfall', marker='o')
    plt.plot(season_data['Year'], season_data['Max_Rainfall'], label=f'{season} Max Rainfall', marker='o')
plt.title('Minimum and Maximum Rainfall Over the Years for Each Season')
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.grid(True)
plt.xticks(data['Year'].unique())  # Setting x-axis ticks to only show years
plt.show()

# %%
# Parameter Visualization
# Plotting minimum and maximum temperature over the years for each season
seasons = data['Season'].unique()
plt.figure(figsize=(12, 6))
for season in seasons:
    season_data = data[data['Season'] == season]
    plt.plot(season_data['Year'], season_data['Min_Temperature'], label=f'{season} Min Temp', marker='o')
    plt.plot(season_data['Year'], season_data['Max_Temperature'], label=f'{season} Max Temp', marker='o')
plt.title('Minimum and Maximum Temperature Over the Years for Each Season')
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.xticks(data['Year'].unique())  # Setting x-axis ticks to only show years
plt.show()

# %%
data = pd.read_csv('Lucknow_data.csv')
# Grouping data by season
season_groups = data.groupby('Season')

# Plotting price fluctuation for each season
plt.figure(figsize=(10, 6))
for season, season_data in season_groups:
    plt.plot(season_data['Year'], season_data['Price'], label=season)

plt.title('Price Fluctuation in "Lucknow" Over the Years for Each Season')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.xticks(data['Year'].unique())  # Setting x-axis ticks to only show years
plt.show()

# %%
data = pd.read_csv('Biznaur_data.csv')

# Grouping data by season
season_groups = data.groupby('Season')

# Plotting price fluctuation for each season
plt.figure(figsize=(10, 6))
for season, season_data in season_groups:
    plt.plot(season_data['Year'], season_data['Price'], label=season)

plt.title('Price Fluctuation in "Biznaur" Over the Years for Each Season')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.xticks(data['Year'].unique())  # Setting x-axis ticks to only show years
plt.show()

# %%
data = pd.read_csv('Muzaffarnagar_data.csv')

# Grouping data by season
season_groups = data.groupby('Season')

# Plotting price fluctuation for each season
plt.figure(figsize=(10, 6))
for season, season_data in season_groups:
    plt.plot(season_data['Year'], season_data['Price'], label=season)

plt.title('Price Fluctuation in "Muzaffarnagar" Over the Years for Each Season')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.xticks(data['Year'].unique())  # Setting x-axis ticks to only show years
plt.show()

# %%
data = pd.read_csv('Saharanpur_data.csv')

# Grouping data by season
season_groups = data.groupby('Season')

# Plotting price fluctuation for each season
plt.figure(figsize=(10, 6))
for season, season_data in season_groups:
    plt.plot(season_data['Year'], season_data['Price'], label=season)

plt.title('Price Fluctuation in "Saharanpur" Over the Years for Each Season')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.xticks(data['Year'].unique())  # Setting x-axis ticks to only show years
plt.show()
